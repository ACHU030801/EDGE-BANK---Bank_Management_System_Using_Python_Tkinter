# %%
import sqlite3

#DATABASE OPERATIONS

try:
    con=sqlite3.connect("edge_bank2.sqlite")
    print("Connected Successfully")
except Error as e :
    print(str(e))
# Out:
# Connected Successfully

# %%
#Creating Table Student
query="create table account2(accntno integer primary key,fullname text,address text,phone text,adhar text,gender text, dob text,nominee text,pass text,balance integer)"
cursor=con.cursor()
cursor.execute(query)
con.commit()

# %%
#Creating Table Student
query="create table loan3(loanid integer primary key autoincrement,accntno integer,emp text,pro text,income text,amount text,duration text,status text)"
cursor=con.cursor()
cursor.execute(query)
con.commit()

# %%
cursor=con.cursor()
cursor.execute('insert into account2 (accntno,fullname,address,phone,adhar,gender,dob,nominee,pass,balance) values(?,?,?,?,?,?,?,?,?,?)',(4012119001001,'Mr Ashish','Ashish Nivas Puthiyidom Kerala 690502','6238830771','8976 5678 4530','1','04-07-2001','Arvind- Father','ashish@2001',15000))
con.commit()

# %%
cursor=con.cursor()
row=cursor.execute('SELECT * from account2')
records=row.fetchall()
for i in records:
    print(i)
con.commit()
# Out:
# (4012119001000, 'Mr Achu', 'Gangalayam Krishnapuram Kerala 690533', '7034668646', '8976 5678 4567', '1', '03-08-2001', 'Sindhu- Mother', 'achu@2001', 10000)
# (4012119001001, 'Mr Ashish', 'Ashish Nivas Puthiyidom Kerala 690502', '6238830771', '8976 5678 4530', '1', '04-07-2001', 'Arvind- Father', 'ashish@2001', 15000)

# %%
cursor=con.cursor()
row=cursor.execute('SELECT * from loan3')
records=row.fetchall()
for i in records:
    print(i)
con.commit()

# %%
import pandas as pd
import numpy as np
train=pd.read_csv('train.csv')
train.Loan_Status=train.Loan_Status.map({'Y':1,'N':0})
Loan_Status=train.Loan_Status
train.drop('Loan_Status',axis=1,inplace=True)

test=pd.read_csv('test.csv')
LoanID=test.Loan_ID
data=train.append(test)
data.Gender=data.Gender.map({'Male':1,'Female':0})
data.Married=data.Married.map({'Yes':1,'No':0})
data.Dependents=data.Dependents.map({'0':0,'1':1,'2':2,'3+':3})
data.Education=data.Education.map({'Graduate':1,'Not Graduate':0})
data.Self_Employed=data.Self_Employed.map({'Yes':1,'No':0})
data.Property_Area=data.Property_Area.map({'Rural':0,'Semiurban':1,'Urban':2})
data.Credit_History.fillna(np.random.randint(0,2),inplace=True)
data.Loan_Amount_Term.fillna(data.Loan_Amount_Term.mean(),inplace=True)
data.LoanAmount.fillna(data.LoanAmount.median(),inplace=True)
data.Self_Employed.fillna(np.random.randint(0,2),inplace=True)
data.Dependents.fillna(data.Dependents.median(),inplace=True)
data.Married.fillna(np.random.randint(0,2),inplace=True)
data.Gender.fillna(np.random.randint(0,2),inplace=True)
data.drop('Loan_ID',inplace=True,axis=1)
x_train=data.iloc[:614,]
y_train=Loan_Status
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_train,y_train,random_state=0)
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression(random_state = 0)
LR.fit(x_train, y_train)
# Predicting the Test set results
y_pred = LR.predict(x_test)
# Measuring Accuracy
from sklearn import metrics
print('The accuracy of Logistic Regression is: ', metrics.accuracy_score(y_pred, y_test))
# Out:
# The accuracy of Logistic Regression is:  0.8116883116883117
# C:\Users\hp\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
t=LR.predict([[0,0.0,0.0,1,0.0,16,5000.0,10000.0,36.0,1.0,0]])
print(t)

# %%
import tkinter as tk
from tkinter import *
from tkinter.messagebox import *
from tkinter import ttk

global root
root=tk.Tk()
root.title('Edge Bank')
root.geometry('1700x900')
root['background']='#2e2b2b'



def logout():
    w2.destroy()
    root.deiconify()




def backinfo():
    ac.withdraw()



def accinfo():
    global ac
    ac=tk.Toplevel(w2)
    ac.title('Edge Bank')
    ac.geometry('1700x900')
    ac['background']='#2e2b2b'
    
    l18= Label(ac,font=( 'Times' ,60, 'bold' ),fg="blue",bg="#2e2b2b", text = "Edge Bank").place(x = 580,y = 160)
    l19= Label(ac,font=( 'Times' ,30, 'bold' ),fg="white",bg="#2e2b2b", text = "Account Information").place(x = 620,y = 260)
    
    style = ttk.Style()
    style.theme_use('clam')


    tree = ttk.Treeview(ac, column=("ACCOUNT NUMBER","FULL NAME","ADDRESS",'PHONE','ADHAR','GENDER','DOB','NOMINEE'), show='headings', height=5)
    tree.column("# 1", anchor=CENTER)
    tree.heading("# 1", text="ACCOUNT NO")
    tree.column("# 2", anchor=CENTER)
    tree.heading("# 2", text="FULL NAME")
    tree.column("# 3", anchor=CENTER)
    tree.heading("# 3", text="ADDRESS")
    tree.column("# 4", anchor=CENTER)
    tree.heading("# 4", text="PHONE")
    tree.column("# 5", anchor=CENTER)
    tree.heading("# 5", text="ADHAR")
    tree.column("# 6", anchor=CENTER)
    tree.heading("# 6", text="GENDER")
    tree.column("# 7", anchor=CENTER)
    tree.heading("# 7", text="DOB")
    tree.column("# 8", anchor=CENTER)
    tree.heading("# 8", text="NOMINEE")
    
    mycursor = con.cursor()
    mycursor.execute("SELECT accntno,fullname,address,phone,adhar,gender,dob,nominee from account2 where accntno=?",(accn,))
    records = mycursor.fetchall()
    records=tuple(records)
    print(records)
    for i in records:
        a,b,c,d,e,f,g,h=i
        tree.insert('', 'end', text="1", values=(a,b,c,d,e,f,g,h))
    
    Button(ac, text='Back',width=20,bg='blue',fg='white',command=backinfo).place(x=700,y=500)

    tree.pack()
    ac.mainloop()
       
    
    
    
    
    
    


def homenew():
    
    global w2
    w1.withdraw()
    w2=tk.Toplevel(w1)
    w2.title('Edge Bank')
    w2.geometry('1700x900')
    w2['background']='#2e2b2b'
    
    l17= Label(w2,font=( 'Times' ,60, 'bold' ),fg="blue",bg="#2e2b2b", text = "Edge Bank").place(x = 580,y = 50)
    
    Button(w2, text='Loan Application Form',width=60,height=3,bg='red',fg='white',command=loan).place(x=560,y=250)
    Button(w2, text='View Loan Status',width=60,height=3,bg='red',fg='white',command=view).place(x=560,y=320)
    Button(w2, text='Account Transfer',width=60,height=3,bg='red',fg='white',command=transf).place(x=560,y=390)
    Button(w2, text='Balance Enquiry',width=60,height=3,bg='red',fg='white',command=bal).place(x=560,y=460)
    Button(w2, text='Edit Your Profile',width=60,height=3,bg='red',fg='white',command=updatep).place(x=560,y=530)
    Button(w2, text='Account Information',width=60,height=3,bg='red',fg='white',command=accinfo).place(x=560,y=600)
    Button(w2, text='Logout',width=60,height=3,bg='red',fg='white',command=logout).place(x=560,y=670)
    
    
    
    
    w2.mainloop()

def create():
    
    cursor=con.cursor()
    row=cursor.execute('SELECT accntno FROM account2 ORDER BY accntno DESC LIMIT 1')
    records=row.fetchall()
    for i in records:
        print(i)
    con.commit()
    i=list(i)
    i[0]=i[0]+1
    print(i[0])
    global accn
    accn=i[0]
    print(accn)
    
    name=fullname.get()
    
    fn=s.get()+" "+fullname.get()
    print(fn)
    
    add=address.get()+" "+city.get()+' '+state.get()+' '+pin.get()
    print(add)
    
    ph=phone.get()
    print(ph)
    
    ad=adhar.get()
    print(ad)
    
    g=gender.get()
    print(g)
    
    d=dob.get()
    n=nominee.get()+" - "+relation.get()
    print(n)
    
    p=passw.get()
    
    row=cursor.execute("SELECT adhar from account1 where adhar=?",(ad,))
    records = row.fetchall()
    if (not fn) or (not add) or (not ph) or(not ad) or(not g) or(not d) or(not n) or(not p):
        print(showinfo("showinfo", "Please fill all the Fields"))
    elif len(ph)!=10:
        print(showinfo("showinfo", "Enter a Valid Phone no"))
    elif len(p)<8:
        print(showinfo("showinfo", "Password must be atleast 8 characters"))
    elif(records==[]):
        cursor.execute('insert into account2 (accntno,fullname,address,phone,adhar,gender,dob,nominee,pass,balance) values(?,?,?,?,?,?,?,?,?,?)',(accn,fn,add,ph,ad,g,d,n,p,0))
        con.commit()
        print(showinfo("showinfo", "Dear "+name+", Congratulations!!! Your Bank Account is Successfully Created and Your Account No is "+str(accn)))
        homenew()
    else:
        print(showinfo("showinfo", "Dear "+name+", Bank account corresponding to the adhar no already exists"))


def new():
    root.withdraw()
    global w1
    w1=tk.Toplevel(root)
    w1.title('Edge Bank')
    w1.geometry('1700x900')
    w1['background']='#2e2b2b'
    
    global s
    global fullname
    global address
    global city
    global pin
    global state
    global passw
    global phone
    global  adhar
    global dob
    global gender
    global nominee
    global relation
    
    s=StringVar()
    fullname=StringVar()
    address=StringVar()
    city=StringVar()
    pin=StringVar()
    state=StringVar()
    passw=StringVar()
    phone=StringVar()
    adhar=StringVar()
    dob=StringVar()
    gender=StringVar()
    nominee=StringVar()
    relation=StringVar()
    
    l3= Label(w1,font=( 'Times' ,60, 'bold' ),fg="blue",bg="#2e2b2b", text = "Edge Bank").place(x = 580,y = 50)
    
    l4= Label(w1,font=( 'Times' ,30, 'bold' ),fg="white",bg="#2e2b2b", text = "Open Your Savings Account").place(x = 500,y = 180)
    
    l5= Label(w1,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Full Name",width=10).place(x = 150,y = 260)
    list1 = ['Mr','Mrs'];
    droplist=OptionMenu(w1,s, *list1)
    droplist.config(width=8)
    s.set('Select')
    droplist.place(x=320,y=260)
    entry_1 = Entry(w1,font=('ariel' ,18,'bold'),bg="white",textvar=fullname)
    entry_1.place(x=420,y=260)
    
    l6= Label(w1,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Address",width=10).place(x = 150,y = 320)
    entry_2 = Entry(w1,font=('ariel' ,18,'bold'),bg="white",textvar=address)
    entry_2.place(x=420,y=320)
    
    l7= Label(w1,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "City",width=10).place(x = 150,y = 380)
    entry_3 = Entry(w1,font=('ariel' ,18,'bold'),bg="white",textvar=city)
    entry_3.place(x=420,y=380)
    
    l8= Label(w1,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "State",width=10).place(x = 150,y = 440)
    entry_4 = Entry(w1,font=('ariel' ,18,'bold'),bg="white",textvar=state)
    entry_4.place(x=420,y=440)
    
    l9= Label(w1,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Pincode",width=10).place(x = 150,y = 500)
    entry_5 = Entry(w1,font=('ariel' ,18,'bold'),bg="white",textvar=pin)
    entry_5.place(x=420,y=500)
    
    l10= Label(w1,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Phone Number",width=10).place(x = 150,y = 560)
    entry_6 = Entry(w1,font=('ariel' ,18,'bold'),bg="white",textvar=phone)
    entry_6.place(x=420,y=560)
    
    l11= Label(w1,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Gender",width=10).place(x = 900,y = 260)
    Radiobutton(w1, text="Male",font=('ariel' ,9,'bold'),bg="white",padx = 8, variable=gender, value=1).place(x=1100,y=260)
    Radiobutton(w1, text="Female",font=('ariel' ,9,'bold'),bg="white",padx = 8, variable=gender, value=2).place(x=1180,y=260)
    Radiobutton(w1, text="Others",font=('ariel' ,9,'bold'),bg="white",padx = 8, variable=gender, value=3).place(x=1275,y=260)
    
    l12= Label(w1,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "DOB",width=10).place(x = 900,y = 320)
    entry_7 = Entry(w1,font=('ariel' ,18,'bold'),bg="white",textvar=dob)
    entry_7.place(x=1100,y=320)
    
    l13= Label(w1,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Adhar Number",width=10).place(x = 900,y = 380)
    entry_8 = Entry(w1,font=('ariel' ,18,'bold'),bg="white",textvar=adhar)
    entry_8.place(x=1100,y=380)
    
    l14= Label(w1,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Nominee",width=10).place(x = 900,y = 440)
    entry_9 = Entry(w1,font=('ariel' ,18,'bold'),bg="white",textvar=nominee)
    entry_9.place(x=1100,y=440)
    
    l15= Label(w1,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Relation",width=10).place(x = 900,y = 500)
    entry_10 = Entry(w1,font=('ariel' ,18,'bold'),bg="white",textvar=relation)
    entry_10.place(x=1100,y=500)
    
    l16= Label(w1,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Password",width=10).place(x = 900,y = 560)
    entry_11 = Entry(w1,font=('ariel' ,18,'bold'),bg="white",textvar=passw)
    entry_11.place(x=1100,y=560)
    
    Button(w1, text='Create Your account',width=40,bg='blue',fg='white',command=create).place(x=650,y=620)
    
    w1.mainloop()



def backedit():
    up.withdraw()


def editpassword():
    p=passw.get()
    if not p:
        print(showinfo("showinfo", "Please fill all the Fields"))
    elif len(p)<8:
        print(showinfo("showinfo", "Password must be 8 characters"))
    else:
        cursor=con.cursor()
        cursor.execute('UPDATE account2 SET pass = ? WHERE accntno = ?',(p,accn))
        print(showinfo("showinfo", "Successfully Changed"))
        con.commit()

def editgender():
    g=gender.get()
    if not g:
        print(showinfo("showinfo", "Please fill all the Fields"))
    else:
        cursor=con.cursor()
        cursor.execute('UPDATE account2 SET gender = ? WHERE accntno = ?',(g,accn))
        print(showinfo("showinfo", "Successfully Changed"))
        con.commit()

def editphone():
    p=phone.get()
    if not p:
        print(showinfo("showinfo", "Please fill all the Fields"))
    elif len(p)!=10:
        print(showinfo("showinfo", "Enter a Valid Phone number"))
    else:
        cursor=con.cursor()
        cursor.execute('UPDATE account2 SET phone = ? WHERE accntno = ?',(p,accn))
        print(showinfo("showinfo", "Successfully Changed"))
        con.commit()
        

def editname():
    print('edit')
    a=s.get()
    name=fullname.get()
    name=a+" "+name
    print(name)
    if not name:
        print(showinfo("showinfo", "Please fill all the Fields"))
    else:
        cursor=con.cursor()
        cursor.execute('UPDATE account2 SET fullname = ? WHERE accntno = ?',(name,accn))
        print(showinfo("showinfo", "Successfully Changed"))
        con.commit()
        
        

def updatep():
    global up
    up=tk.Toplevel(w2)
    up.title('Edge Bank')
    up.geometry('1700x900')
    up['background']='#2e2b2b'
    
    
    global s
    global fullname
    global passw
    global phone
    global gender
    
    s=StringVar()
    fullname=StringVar()
    passw=StringVar()
    phone=StringVar()
    gender=StringVar()
    
    l18= Label(up,font=( 'Times' ,60, 'bold' ),fg="blue",bg="#2e2b2b", text = "Edge Bank").place(x = 580,y = 20)
    l19= Label(up,font=( 'Times' ,30, 'bold' ),fg="white",bg="#2e2b2b", text = "Edit Your Profile").place(x = 620,y = 160)
    
    
    l5= Label(up,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Full Name",width=10).place(x = 450,y = 260)
    list1 = ['Mr','Mrs'];
    droplist=OptionMenu(up,s, *list1)
    droplist.config(width=8)
    s.set('Select')
    droplist.place(x=620,y=260)
    entry_1 = Entry(up,font=('ariel' ,18,'bold'),bg="white",textvar=fullname)
    entry_1.place(x=720,y=260)
    
    Button(up, text='Edit',width=20,bg='blue',fg='white',command=editname).place(x=1000,y=260)
    
    l10= Label(up,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Phone Number",width=10).place(x = 450,y = 320)
    entry_6 = Entry(up,font=('ariel' ,18,'bold'),bg="white",textvar=phone)
    entry_6.place(x=720,y=320)
    
    Button(up, text='Edit',width=20,bg='blue',fg='white',command=editphone).place(x=1000,y=320)
    
    
    l11= Label(up,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Gender",width=10).place(x = 450,y = 380)
    Radiobutton(up, text="Male",font=('ariel' ,9,'bold'),bg="white",padx = 8, variable=gender, value=1).place(x=720,y=380)
    Radiobutton(up, text="Female",font=('ariel' ,9,'bold'),bg="white",padx = 8, variable=gender, value=2).place(x=800,y=380)
    Radiobutton(up, text="Others",font=('ariel' ,9,'bold'),bg="white",padx = 8, variable=gender, value=3).place(x=900,y=380)
    
    Button(up, text='Edit',width=20,bg='blue',fg='white',command=editgender).place(x=1000,y=380)
    
    l16= Label(up,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Password",width=10).place(x = 450,y = 440)
    entry_11 = Entry(up,font=('ariel' ,18,'bold'),bg="white",textvar=passw)
    entry_11.place(x=720,y=440)
    
    Button(up, text='Edit',width=20,bg='blue',fg='white',command=editpassword).place(x=1000,y=440)
    
    Button(up, text='Back',width=20,bg='blue',fg='white',command=backedit).place(x=1300,y=20)
    
    up.mainloop()

def bal():
    cursor=con.cursor()
    cursor.execute("SELECT balance from account2 where accntno=?",(accn,))
    records = cursor.fetchall()
    for i in records:
        print(i)
    i=list(i)
    balf=i[0]
    if balf<500:
        print(showinfo("showinfo", "Your Balance is Below the Minimum Balance... Please Maintain the Minimum Balance.... Account Balance is "+str(balf)))
    else:
        print(showinfo("showinfo", "Account Balance is "+str(balf)))
    con.commit()


def transferto():
    print('transfer')
    t=to.get()
    a=am.get()
    cursor=con.cursor()
    cursor.execute("SELECT balance from account2 where accntno=?",(accn,))
    records = cursor.fetchall()
    for i in records:
        print(i)
    i=list(i)
    balf=i[0]
    print
    cursor.execute("SELECT balance from account2 where accntno=?",(t,))
    records = cursor.fetchall()
    for j in records:
        print(j)
    j=list(j)
    balt=j[0]
    if balf<a:
        print(showinfo("showinfo", "Insufficient Balance"))
    else:
        from_m=balf-a
        to_m=balt+a
        print(type(to_m))
        print(type(to))
        print(type(from_m))
        print(type(accn))
        print(type(t))
        cursor.execute('UPDATE account2 SET balance = ? WHERE accntno = ?',(from_m,accn))
        cursor.execute('UPDATE account2 SET balance = ? WHERE accntno = ?',(to_m,t))
        print(showinfo("showinfo", "Money Transfered successfully"))
        con.commit()

def backtransf():
    w5.withdraw()


def transf():
    global w5
    w5=tk.Toplevel(w2)
    w5.title('Edge Bank')
    w5.geometry('1700x900')
    w5['background']='#2e2b2b'
    
    global to
    global am
    to=IntVar()
    am=IntVar()
    
    l18= Label(w5,font=( 'Times' ,60, 'bold' ),fg="blue",bg="#2e2b2b", text = "Edge Bank").place(x = 580,y = 20)
    l19= Label(w5,font=( 'Times' ,30, 'bold' ),fg="white",bg="#2e2b2b", text = "Money Transfer").place(x = 630,y = 160)
    
    l20= Label(w5,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Account No(to)",width=17).place(x = 450,y = 250)
    entry_12 = Entry(w5,font=('ariel' ,18,'bold'),bg="white",textvar=to)
    entry_12.place(x=750,y=250)
    
    l20= Label(w5,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Amount",width=17).place(x = 450,y = 310)
    entry_12 = Entry(w5,font=('ariel' ,18,'bold'),bg="white",textvar=am)
    entry_12.place(x=750,y=310)
    
    
    Button(w5, text='Transfer',width=37,height=4,bg='blue',fg='white',command=transferto).place(x=620,y=370)
    Button(w5, text='Back',width=20,bg='blue',fg='white',command=backtransf).place(x=1300,y=20)
    
    
    w5.mainloop()


def backview():
    w4.withdraw()



def view():
    global w4
    w4=tk.Toplevel(w2)
    w4.title('Edge Bank')
    w4.geometry('1700x900')
    w4['background']='#2e2b2b'
    
    l18= Label(w4,font=( 'Times' ,60, 'bold' ),fg="blue",bg="#2e2b2b", text = "Edge Bank").place(x = 580,y = 160)
    l19= Label(w4,font=( 'Times' ,30, 'bold' ),fg="white",bg="#2e2b2b", text = "Loan Status").place(x = 620,y = 260)
    
    style = ttk.Style()
    style.theme_use('clam')


    tree = ttk.Treeview(w4, column=("ACCOUNT NUMBER","LOAN AMOUNT","STATUS"), show='headings', height=5)
    tree.column("# 1", anchor=CENTER)
    tree.heading("# 1", text="ACCOUNT NO")
    tree.column("# 2", anchor=CENTER)
    tree.heading("# 2", text="LOAN AMOUNT")
    tree.column("# 3", anchor=CENTER)
    tree.heading("# 3", text="STATUS")
    
    mycursor = con.cursor()
    mycursor.execute("SELECT accntno,amount,status from loan3 where accntno=?",(accn,))
    records = mycursor.fetchall()
    if(records==[]):
        print(showinfo("showinfo", "You have not Applied Any Loan"))
    print(records)
    records=tuple(records)
    print(records)
    for i in records:
        a,b,c=i
        tree.insert('', 'end', text="1", values=(a,b,c))
    
    Button(w4, text='Back',width=20,bg='blue',fg='white',command=backview).place(x=700,y=500)

    tree.pack()
    w4.mainloop()
       


def backloan():
    w3.withdraw()

def loan_fn():
    ac=acc.get()
    ge=gen.get()
    ma=mar.get()
    de=dep.get()
    ed=edu.get()
    em=emp.get()
    pr=pro.get()
    cr=cre.get()
    ap=app.get()
    co=coa.get()
    lo=loa.get()
    du=dur.get()
    
    t=LR.predict([[ge,ma,de,ed,em,ap,co,lo,du,cr,pr]])
    print(t)
    if t[0]==1:
        status="Accepted"
        print(showinfo("showinfo","Loan Application Submitted Successfully!!!....Please check Your Loan Status"))
        print(status)
    else:
        status="Pending"
        print(showinfo("showinfo","Loan Application Submitted Successfully!!!....Please check Your Loan Status"))
        print(status)
    cursor=con.cursor()
    cursor.execute('insert into loan3 (accntno,emp,pro,income,amount,duration,status) values(?,?,?,?,?,?,?)',(accn,em,pr,ap,lo,du,status))
    con.commit()
    

def doll():
    i=inr.get()
    dol = i//64
    print(showinfo("showinfo",str(i)+" Rs is "+str(dol)+"$"))

def loan():
    
    global w3
    w3=tk.Toplevel(w2)
    w3.title('Edge Bank')
    w3.geometry('1700x900')
    w3['background']='#2e2b2b'
    
    global acc
    global gen
    global mar
    global dep
    global edu
    global emp
    global pro
    global cre
    global app
    global coa
    global loa
    global dur
    
    acc= IntVar()
    gen=StringVar()
    mar=StringVar()
    dep=StringVar()
    edu=StringVar()
    emp=StringVar()
    pro=StringVar()
    cre=StringVar()
    app=StringVar()
    coa=StringVar()
    loa=StringVar()
    dur=StringVar()
    
    
    l18= Label(w3,font=( 'Times' ,60, 'bold' ),fg="blue",bg="#2e2b2b", text = "Edge Bank").place(x = 580,y = 20)
    l19= Label(w3,font=( 'Times' ,30, 'bold' ),fg="white",bg="#2e2b2b", text = "Loan Application Form").place(x = 570,y = 100)
    
    l20= Label(w3,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Account No",width=17).place(x = 130,y = 180)
    entry_12 = Entry(w3,font=('ariel' ,18,'bold'),bg="white",textvar=acc)
    entry_12.place(x=420,y=180)
    
    l21= Label(w3,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Gender",width=17).place(x = 130,y = 220)
    Radiobutton(w3, text="Male",font=('ariel' ,9,'bold'),bg="white",padx = 8, variable=gen, value=1).place(x=420,y=220)
    Radiobutton(w3, text="Female",font=('ariel' ,9,'bold'),bg="white",padx = 8, variable=gen, value=0).place(x=520,y=220)
    
    l22= Label(w3,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Marital Status",width=17).place(x = 130,y = 260)
    Radiobutton(w3, text="Yes",font=('ariel' ,9,'bold'),bg="white",padx = 8, variable=mar, value=1).place(x=420,y=260)
    Radiobutton(w3, text="No",font=('ariel' ,9,'bold'),bg="white",padx = 8, variable=mar, value=0).place(x=520,y=260)
    
    l23= Label(w3,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Dependents",width=17).place(x = 130,y = 300)
    Radiobutton(w3, text="No",font=('ariel' ,9,'bold'),bg="white",padx = 8, variable=dep, value=0).place(x=420,y=300)
    Radiobutton(w3, text="One",font=('ariel' ,9,'bold'),bg="white",padx = 8, variable=dep, value=1).place(x=520,y=300)
    Radiobutton(w3, text="Two",font=('ariel' ,9,'bold'),bg="white",padx = 8, variable=dep, value=2).place(x=620,y=300)
    Radiobutton(w3, text="More than two",font=('ariel' ,9,'bold'),bg="white",padx = 8, variable=dep, value=3).place(x=720,y=300)
    
    l24= Label(w3,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Education",width=17).place(x = 130,y = 340)
    Radiobutton(w3, text="Graduate",font=('ariel' ,9,'bold'),bg="white",padx = 8, variable=edu, value=1).place(x=420,y=340)
    Radiobutton(w3, text="Not Graduate",font=('ariel' ,9,'bold'),bg="white",padx = 8, variable=edu, value=0).place(x=520,y=340)
    
    l25= Label(w3,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Employment Status",width=17).place(x = 130,y = 380)
    Radiobutton(w3, text="Job",font=('ariel' ,9,'bold'),bg="white",padx = 8, variable=emp, value=1).place(x=420,y=380)
    Radiobutton(w3, text="Bussiness",font=('ariel' ,9,'bold'),bg="white",padx = 8, variable=emp, value=0).place(x=520,y=380)
    
    l26= Label(w3,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Property Area",width=17).place(x = 130,y = 420)
    Radiobutton(w3, text="Rural",font=('ariel' ,9,'bold'),bg="white",padx = 8, variable=pro, value=0).place(x=420,y=420)
    Radiobutton(w3, text="Semi-Urban",font=('ariel' ,9,'bold'),bg="white",padx = 8, variable=pro, value=1).place(x=520,y=420)
    Radiobutton(w3, text="Urban",font=('ariel' ,9,'bold'),bg="white",padx = 8, variable=pro, value=2).place(x=640,y=420)
    
    l27= Label(w3,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Credit Score",width=17).place(x = 130,y = 460)
    Radiobutton(w3, text="Between 300 to 500",font=('ariel' ,9,'bold'),bg="white",padx = 8, variable=cre, value=0).place(x=420,y=460)
    Radiobutton(w3, text="Above 500",font=('ariel' ,9,'bold'),bg="white",padx = 8, variable=cre, value=1).place(x=620,y=460)
    
    l28= Label(w3,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Applicant Income($)",width=17).place(x = 130,y = 500)
    entry_13 = Entry(w3,font=('ariel' ,18,'bold'),bg="white",textvar=app)
    entry_13.place(x=420,y=500)
    
    l29= Label(w3,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Co-Applicant Income($)",width=17).place(x = 130,y = 540)
    entry_14 = Entry(w3,font=('ariel' ,18,'bold'),bg="white",textvar=coa)
    entry_14.place(x=420,y=540)
    
    l30= Label(w3,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Loan Amount($)",width=17).place(x = 130,y = 580)
    entry_15 = Entry(w3,font=('ariel' ,18,'bold'),bg="white",textvar=loa)
    entry_15.place(x=420,y=580)
    
    l31= Label(w3,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Loan Duration",width=17).place(x = 130,y = 620)
    Radiobutton(w3, text="2 month",font=('ariel' ,9,'bold'),bg="white",padx = 8, variable=dur, value=60).place(x=420,y=620)
    Radiobutton(w3, text="6 month",font=('ariel' ,9,'bold'),bg="white",padx = 8, variable=dur, value=180).place(x=520,y=620)
    Radiobutton(w3, text="8 month",font=('ariel' ,9,'bold'),bg="white",padx = 8, variable=dur, value=240).place(x=620,y=620)
    Radiobutton(w3, text="1 year",font=('ariel' ,9,'bold'),bg="white",padx = 8, variable=dur, value=360).place(x=720,y=620)
    Radiobutton(w3, text="16 month",font=('ariel' ,9,'bold'),bg="white",padx = 8, variable=dur, value=480).place(x=820,y=620)
    
    Button(w3, text='Apply Loan',width=40,bg='blue',fg='white',command=loan_fn).place(x=420,y=660)
    
    l30= Label(w3,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Loan Amount($)",width=17).place(x = 130,y = 580)
    entry_15 = Entry(w3,font=('ariel' ,18,'bold'),bg="white",textvar=loa)
    entry_15.place(x=420,y=580)
    global inr
    inr=IntVar()
    
    l30= Label(w3,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Enter Amount in (Rs)",width=17).place(x = 940,y = 260)
    entry_15 = Entry(w3,font=('ariel' ,18,'bold'),bg="white",textvar=inr)
    entry_15.place(x=1200,y=260)
    Button(w3, text='Dollar($)',width=37,bg='blue',fg='white',command=doll).place(x=1200,y=300)
    
    
    Button(w3, text='Back',width=20,bg='blue',fg='white',command=backloan).place(x=1300,y=20)
    
    
    
    w3.mainloop()


def homeexist():
    
    global w2
    w6.withdraw()
    w2=tk.Toplevel(w6)
    w2.title('Edge Bank')
    w2.geometry('1700x900')
    w2['background']='#2e2b2b'
    
    l17= Label(w2,font=( 'Times' ,60, 'bold' ),fg="blue",bg="#2e2b2b", text = "Edge Bank").place(x = 580,y = 50)
    
    Button(w2, text='Loan Application Form',width=60,height=3,bg='red',fg='white',command=loan).place(x=560,y=250)
    Button(w2, text='View Loan Status',width=60,height=3,bg='red',fg='white',command=view).place(x=560,y=320)
    Button(w2, text='Account Transfer',width=60,height=3,bg='red',fg='white',command=transf).place(x=560,y=390)
    Button(w2, text='Balance Enquiry',width=60,height=3,bg='red',fg='white',command=bal).place(x=560,y=460)
    Button(w2, text='Edit Your Profile',width=60,height=3,bg='red',fg='white',command=updatep).place(x=560,y=530)
    Button(w2, text='Account Information',width=60,height=3,bg='red',fg='white',command=accinfo).place(x=560,y=600)
    Button(w2, text='Logout',width=60,height=3,bg='red',fg='white',command=logout).place(x=560,y=670)
    
    
    
    
    w2.mainloop()

def login():
    print('login')
    
    global accn
    accn=acct.get()
    p=passw1.get()
    print(accn)
    print(p)
    
    if (not accn) or (not p):
        print(showinfo("showinfo","Please Fill All details"))
    else:
        cursor=con.cursor()
        cursor.execute("SELECT pass from account2 where accntno=?",(accn,))
        records = cursor.fetchall()
        if records==[]:
            print(showinfo("showinfo","Account No is Incorrect"))
        else:
            
            for i in records:
                print(i)
            i=list(i)
            pa=i[0]
            if p==pa:
                print(showinfo("showinfo", "Login Successfull"))
                homeexist()
            else:
                print(showinfo("showinfo", "Password Incorrect"))

                
                
                
                
def update1234():
    print('gjhsj')
    a=s.get()
    b=st.get()
    acc=a[1:2]
    print(a)
    print(b)
 

    if not a :
        print(showinfo("showinfo", "Please All the Fields"))
    elif not b :
        print(showinfo("showinfo", "Please All the Fields"))  
    else:
        cursor=con.cursor()
        con.execute("UPDATE loan3 SET status = ? WHERE loanid = ?",(b,acc))
        print(showinfo("showinfo", "Update Successfully")) 
        

def viewapp():
    global s5
    s5=tk.Toplevel(s1)
    s5.title('Edge Bank')
    s5.geometry('1700x900')
    s5['background']='#2e2b2b'
    
    l18= Label(s5,font=( 'Times' ,60, 'bold' ),fg="blue",bg="#2e2b2b", text = "Edge Bank").place(x = 580,y = 160)
    
    style = ttk.Style()
    style.theme_use('clam')


    tree = ttk.Treeview(s5, column=("LOAN ID","ACCOUNT NUMBER","EMPLOYMENT","PROPERTY AREA",'INCOME',"LOAN AMOUNT",'DURATION','STATUS'), show='headings', height=5)
    tree.column("# 1", anchor=CENTER)
    tree.heading("# 1", text="LOAN ID")
    tree.column("# 2", anchor=CENTER)
    tree.heading("# 2", text="ACCOUNT NO")
    tree.column("# 3", anchor=CENTER)
    tree.heading("# 3", text="EMPLOYMENT")
    tree.column("# 4", anchor=CENTER)
    tree.heading("# 4", text="PROPERTY AREA")
    tree.column("# 5", anchor=CENTER)
    tree.heading("# 5", text="INCOME")
    tree.column("# 6", anchor=CENTER)
    tree.heading("# 6", text="LOAN AMOUNT")
    tree.column("# 7", anchor=CENTER)
    tree.heading("# 7", text="DURATION")
    tree.column("# 8", anchor=CENTER)
    tree.heading("# 8", text="STATUS")

    
    mycursor = con.cursor()
    mycursor.execute("SELECT * from loan3" )
    records = mycursor.fetchall()
    records=tuple(records)
    print(records)
    for i in records:
        a,b,c,d,e,f,g,H=i
        tree.insert('', 'end', text="1", values=(a,b,c,d,e,f,g,H))
    
    
    
    mycursor.execute("select loanid from loan3")
    records=mycursor.fetchall()
    print(records)
        
    global s
    global st
    s=StringVar()
    st=StringVar()
        
        
    l5= Label(s5,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Account No",width=10).place(x = 400,y = 360)
    droplist=OptionMenu(s5,s, *records)
    droplist.config(width=8)
    s.set('Select')
    droplist.place(x=400,y=400)
    
    l1=["Accepted","Rejected"]
    
    l5= Label(s5,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Status",width=10).place(x = 600,y = 360)
    droplist=OptionMenu(s5,st, *l1)
    droplist.config(width=8)
    st.set('Select')
    droplist.place(x=600,y=400)
    
    Button(s5, text='Update',width=20,bg='blue',fg='white',command=update1234).place(x=800,y=380)
    
    
    
    Button(s5, text='Back',width=20,bg='blue',fg='white',command=back4).place(x=700,y=500)

    tree.pack()
    s5.mainloop()
    


    


def deleteaccount():
    am=acc.get()
    a=am[1:14]
    if not a:
        print(showinfo("showinfo", "Please Enter a Account number"))
    else:
        cursor=con.cursor()
        rows=cursor.execute("select * from account2 where accntno=?",(a,))
        records=rows.fetchall()
        if(records==[]):
            print(showinfo("showinfo", "Account No doesnot Exist"))
        else:
            cursor.execute("DELETE FROM account2 WHERE accntno = ?",(a,))
            print(showinfo("showinfo", "Deleted Successfully"))
            s4.withdraw()
            viewuser()
        
        

def deleteuser():
    global s4
    s4=tk.Toplevel(s3)
    s4.title('Edge Bank')
    s4.geometry('1700x900')
    s4['background']='#2e2b2b'
    
    global acc
    acc=StringVar()
    
    l18= Label(s4,font=( 'Times' ,60, 'bold' ),fg="blue",bg="#2e2b2b", text = "Edge Bank").place(x = 580,y = 20)
    l19= Label(s4,font=( 'Times' ,30, 'bold' ),fg="white",bg="#2e2b2b", text = "Delete User").place(x = 700,y = 160)
    
    l20= Label(s4,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Account No",width=17).place(x = 430,y = 320)
    mycursor=con.cursor()
    mycursor.execute("select accntno from account2")
    records=mycursor.fetchall()
    print(records)
    droplist=OptionMenu(s4,acc, *records)
    droplist.config(width=8)
    acc.set('Select')
    droplist.place(x=720,y=320)
    
    
    Button(s4, text='Delete',width=20,bg='blue',fg='white',command=deleteaccount).place(x=620,y=380)
    
    Button(s4, text='Back',width=20,bg='blue',fg='white',command=back3).place(x=700,y=500)
    
    s4.mainloop()

def user():
    global s3
    s3=tk.Toplevel(s1)
    s3.title('Edge Bank')
    s3.geometry('1700x900')
    s3['background']='#2e2b2b'
    
    l18= Label(s3,font=( 'Times' ,60, 'bold' ),fg="blue",bg="#2e2b2b", text = "Edge Bank").place(x = 580,y = 20)
    l19= Label(s3,font=( 'Times' ,30, 'bold' ),fg="white",bg="#2e2b2b", text = "User").place(x = 700,y = 160)
    
    
    Button(s3, text='View User',width=60,height=3,bg='red',fg='white',command=viewuser).place(x=560,y=250)
    Button(s3, text='Delete User',width=60,height=3,bg='red',fg='white',command=deleteuser).place(x=560,y=320)
    
    Button(s3, text='Back',width=20,bg='blue',fg='white',command=back2).place(x=700,y=500)

    s3.mainloop()


def back1():
    s2.withdraw()
    
def back2():
    s3.withdraw()
    
def back3():
    s4.withdraw()
    
    

def back4():
    s5.withdraw()
    
def back5():
    s6.withdraw()
    
    
def viewuser():
    global s2
    s2=tk.Toplevel(s3)
    s2.title('Edge Bank')
    s2.geometry('1700x900')
    s2['background']='#2e2b2b'
    
    l18= Label(s2,font=( 'Times' ,60, 'bold' ),fg="blue",bg="#2e2b2b", text = "Edge Bank").place(x = 580,y = 160)
    
    style = ttk.Style()
    style.theme_use('clam')


    tree = ttk.Treeview(s2, column=("ACCOUNT NUMBER","FULL NAME","ADDRESS",'PHONE','ADHAR','GENDER','DOB','NOMINEE','BALANCE'), show='headings', height=5)
    tree.column("# 1", anchor=CENTER)
    tree.heading("# 1", text="ACCOUNT NO")
    tree.column("# 2", anchor=CENTER)
    tree.heading("# 2", text="FULL NAME")
    tree.column("# 3", anchor=CENTER)
    tree.heading("# 3", text="ADDRESS")
    tree.column("# 4", anchor=CENTER)
    tree.heading("# 4", text="PHONE")
    tree.column("# 5", anchor=CENTER)
    tree.heading("# 5", text="ADHAR")
    tree.column("# 6", anchor=CENTER)
    tree.heading("# 6", text="GENDER")
    tree.column("# 7", anchor=CENTER)
    tree.heading("# 7", text="DOB")
    tree.column("# 8", anchor=CENTER)
    tree.heading("# 8", text="NOMINEE")
    tree.column("# 9", anchor=CENTER)
    tree.heading("# 9", text="BALANCE")
    
    mycursor = con.cursor()
    mycursor.execute("SELECT accntno,fullname,address,phone,adhar,gender,dob,nominee,balance from account2" )
    records = mycursor.fetchall()
    records=tuple(records)
    print(records)
    for i in records:
        a,b,c,d,e,f,g,h,J=i
        tree.insert('', 'end', text="1", values=(a,b,c,d,e,f,g,h,J))
    
    Button(s2, text='Back',width=20,bg='blue',fg='white',command=back1).place(x=700,y=500)

    tree.pack()
    s2.mainloop()
                
def log123():
    s1.destroy()
    root.deiconify()
def homeadmin():
    global s1
    s21.withdraw()
    s1=tk.Tk()
    s1.title('Edge Bank')
    s1.geometry('1700x900')
    s1['background']='#2e2b2b'
    
    l18= Label(s1,font=( 'Times' ,60, 'bold' ),fg="blue",bg="#2e2b2b", text = "Edge Bank").place(x = 580,y = 20)
    l19= Label(s1,font=( 'Times' ,30, 'bold' ),fg="white",bg="#2e2b2b", text = "Home").place(x = 700,y = 160)
    
    
    Button(s1, text='User',width=60,height=3,bg='red',fg='white',command=user).place(x=560,y=250)
    Button(s1, text='View Loan Applications',width=60,height=3,bg='red',fg='white',command=viewapp).place(x=560,y=320)
    Button(s1, text='Logout',width=60,height=3,bg='red',fg='white',command=log123).place(x=560,y=390)
    
    
def login1234():
    a=acct.get()
    b=passw1.get()
    if not a:
        print(showinfo("showinfo", "Please Fill All the Fields"))
    elif not b:
        print(showinfo("showinfo", "Please Fill All the Fields"))
    elif a!="Admin123":
        print(showinfo("showinfo", "Username does not exist"))
    elif b!="password":
        print(showinfo("showinfo", "Password Incorrect"))
    else:
        print(showinfo("showinfo", "Login Success"))
        homeadmin()
                
def admin123():
    global s21
    s21=tk.Toplevel(root)
    root.withdraw()
    s21.title('Edge Bank')
    s21.geometry('1700x900')
    s21['background']='#2e2b2b'
    
    global acct
    global passw1
    acct=StringVar()
    passw1=StringVar()
    
    l18= Label(s21,font=( 'Times' ,60, 'bold' ),fg="blue",bg="#2e2b2b", text = "Edge Bank").place(x = 580,y = 20)
    l19= Label(s21,font=( 'Times' ,30, 'bold' ),fg="white",bg="#2e2b2b", text = "LOGIN").place(x = 700,y = 160)
    
    l20= Label(s21,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "User Name",width=17).place(x = 450,y = 250)
    entry_12 = Entry(s21,font=('ariel' ,18,'bold'),bg="white",textvar=acct)
    entry_12.place(x=750,y=250)
    
    l20= Label(s21,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Password",width=17).place(x = 450,y = 310)
    entry_12 = Entry(s21,font=('ariel' ,18,'bold'),bg="white",textvar=passw1)
    entry_12.place(x=750,y=310)
    
    
    Button(s21, text='Sign In',width=37,height=4,bg='blue',fg='white',command=login1234).place(x=620,y=370)
    
    s21.mainloop()

def exist():
    
    global w6
    w6=tk.Toplevel(root)
    root.withdraw()
    w6.title('Edge Bank')
    w6.geometry('1700x900')
    w6['background']='#2e2b2b'
    
    global acct
    global passw1
    acct=IntVar()
    passw1=StringVar()
    
    l18= Label(w6,font=( 'Times' ,60, 'bold' ),fg="blue",bg="#2e2b2b", text = "Edge Bank").place(x = 580,y = 20)
    l19= Label(w6,font=( 'Times' ,30, 'bold' ),fg="white",bg="#2e2b2b", text = "LOGIN").place(x = 700,y = 160)
    
    l20= Label(w6,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Account No",width=17).place(x = 450,y = 250)
    entry_12 = Entry(w6,font=('ariel' ,18,'bold'),bg="white",textvar=acct)
    entry_12.place(x=750,y=250)
    
    l20= Label(w6,font=( 'Times' ,20, 'bold' ),fg="red",bg="black", text = "Password",width=17).place(x = 450,y = 310)
    entry_12 = Entry(w6,font=('ariel' ,18,'bold'),bg="white",textvar=passw1)
    entry_12.place(x=750,y=310)
    
    
    Button(w6, text='Sign In',width=37,height=4,bg='blue',fg='white',command=login).place(x=620,y=370)
    
    w6.mainloop()

l1= Label(root,font=( 'Times' ,80, 'bold' ),fg="red",bg="#2e2b2b", text = "Edge Bank").place(x = 550,y = 50)

l2= Label(root,font=( 'Times' ,30, 'bold' ),fg="white",bg="#2e2b2b", text = "Please select to proceed").place(x = 600,y = 250)

Button(root, text='Existing User',width=20,bg='blue',fg='white',command=exist).place(x=700,y=310)
Button(root, text='New User',width=20,bg='blue',fg='white',command=new).place(x=700,y=360)


Button(root, text='Admin',width=20,bg='blue',fg='white',command=admin123).place(x=700,y=700)

root.mainloop()
# Out:
# ok
# ((1, 4012119001000, '1', '1', '328', '1562', '240', 'Pending'), (2, 4012119001003, '1', '0', '50', '300', '60', 'Accepted'))
# [(1,), (2,)]
# login
# 4012119001001
# ashish@2001
# ('ashish@2001',)
# ok
# ok
# ok
# ok
# ok
# C:\Users\hp\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# C:\Users\hp\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:566: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   X = check_array(X, **check_params)
# [1]
# ok
# Accepted
# [(4012119001001, '781', 'Accepted')]
# ((4012119001001, '781', 'Accepted'),)
# (15200,)
# ok
# transfer
# (15200,)
# (9800,)
# ok
# transfer
# (15200,)
# ...

# %%
# Out:
# ((4012119001002, '1', '1', '7', '15625', '480', 'Accepted'), (4012119001010, '0', '0', '50', '600', '180', 'Rejected'), (4012119001002, '1', '2', '390', '1562', '180', 'Accepted'))
# [(4012119001002,), (4012119001010,), (4012119001002,)]
# gjhsj
# (4012119001010,)
# Accepted
# ok
# ((4012119001002, '1', '1', '7', '15625', '480', 'Accepted'), (4012119001010, '0', '0', '50', '600', '180', 'Accepted'), (4012119001002, '1', '2', '390', '1562', '180', 'Accepted'))
# [(4012119001002,), (4012119001010,), (4012119001002,)]
# ((4012119001002, '1', '1', '7', '15625', '480', 'Accepted'), (4012119001010, '0', '0', '50', '600', '180', 'Accepted'), (4012119001002, '1', '2', '390', '1562', '180', 'Accepted'))
# [(4012119001002,), (4012119001010,), (4012119001002,)]
